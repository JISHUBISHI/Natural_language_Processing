# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("Hi, I am Agnik Bishi")
for token in doc:
    print(token.text , "Vector:",token.has_vector , "OOV:",  token.is_oov)
# Out:
# Hi Vector: True OOV: False
# , Vector: True OOV: False
# I Vector: True OOV: False
# am Vector: True OOV: False
# Agnik Vector: False OOV: True
# Bishi Vector: True OOV: False

# %%
doc[0].vector.shape
# Out:
# (300,)

# %%
base_token  = nlp("Bread")
base_token.vector.shape
# Out:
# (300,)

# %%
doc = nlp("Bread sandwhich burger car tiger humnan wheat")
for token in doc:
    print(f"{token.text} <-> {base_token.text}" , token.similarity(base_token))
# Out:
# Bread <-> Bread 0.9999999766167111
# sandwhich <-> Bread 0.4656919457368121
# burger <-> Bread 0.5440373883702087
# car <-> Bread 0.1644114584391833
# tiger <-> Bread 0.1449235625942581
# humnan <-> Bread 0.0
# wheat <-> Bread 0.6572456428272563
# C:\Users\agnik\AppData\Local\Temp\ipykernel_16436\2085906355.py:3: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   print(f"{token.text} <-> {base_token.text}" , token.similarity(base_token))

# %%
def print_similarity(base_word , words_to_compare):
    base_token =  nlp(base_word)
    doc =  nlp(words_to_compare)
    for token in doc:
        print(f"{token.text} <-> {base_token.text}" , token.similarity(base_token))

# %%
print_similarity("iphone","apple samsung nokia iphone dog kitchen mango")
# Out:
# apple <-> iphone 0.6339781147910419
# samsung <-> iphone 0.6678678014329177
# nokia <-> iphone 0.6658259154109943
# iphone <-> iphone 1.0000000285783557
# dog <-> iphone 0.17431037640553934
# kitchen <-> iphone 0.16262904993953303
# mango <-> iphone 0.24146425999500368

# %%
king = nlp.vocab["king"].vector
man = nlp.vocab["man"].vector
woman = nlp.vocab["woman"].vector
queen = nlp.vocab["queen"].vector

result = king - man + woman

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([result] , [queen])
# Out:
# array([[0.78808445]], dtype=float32)
